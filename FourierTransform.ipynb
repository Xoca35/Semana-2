# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import random
from scipy import integrate

# %%
#Calcular la trans de F usando  la definicion 
#de Trans discreta de Fourier dada por JW Cooley and John Tukey ( 1965 )

def FT(x):
    N = x.shape[0]
    n = np.arange(N)
    k = n.reshape((N, 1))
    M = np.exp(-2j * np.pi * k * n / N)
    return np.dot(M, x)

# %%
N=100

x=np.linspace(0,2*np.pi,N)
y=2*x**2
plt.plot(x,y)

# %%
trans= FT(y)

plt.plot(trans)
